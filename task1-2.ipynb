# %% [markdown]
# ## Day-25 Task

# %% [markdown]
# (Task 1-2)

# %%
import pandas as pd

# %% [markdown]
# ///Load Data://

# %%
data = ({
    'name': ['John Doe',  'Alice',  'Bob', 'Bob', 'Charlie', 'charlie'],
    'age': [25,  30,  22, 22, 28, 28],
    'salary':  [50000, 25000, 10000, 10000, 25000, 30000]      
})
df=pd.DataFrame(data)
print("Original data is:\n",df)
# Out:
# Original data is:
#         name  age  salary
# 0  John Doe   25   50000
# 1     Alice   30   25000
# 2       Bob   22   10000
# 3       Bob   22   10000
# 4   Charlie   28   25000
# 5   charlie   28   30000

# %% [markdown]
# ///Task-1 df.duplicated().sum()

# %%
dup=df.duplicated().sum()
print("Count the Duplicated values:\n",dup)
# Out:
# Count the Duplicated values:
#  1

# %% [markdown]
# ///Task-2 df.drop_duplicates(inplace=True)

# %%
df=df.drop_duplicates()
print("Remove duplicated from dataframe\n",df)
# Out:
# Remove duplicated from dataframe
#         name  age  salary
# 0  John Doe   25   50000
# 1     Alice   30   25000
# 2       Bob   22   10000
# 4   Charlie   28   25000
# 5   charlie   28   30000
