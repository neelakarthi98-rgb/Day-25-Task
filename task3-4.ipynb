# %% [markdown]
# ## Day-25 Task

# %% [markdown]
# ///Task no:3-4

# %%
import pandas as pd

# %% [markdown]
# //Load data://

# %%
data = ({
    'name': ['John Doe',  'Alice',  'Bob', 'Bob', 'Charlie', 'Charlie','robert'],
    'age': [25,  30,  22, 22, 28, 28,28],
    'salary':  [50000, 25000, 10000, 10000, 25000, 30000,15000]      
})
df=pd.DataFrame(data)
print("Original data is:\n",df)
# Out:
# Original data is:
#         name  age  salary
# 0  John Doe   25   50000
# 1     Alice   30   25000
# 2       Bob   22   10000
# 3       Bob   22   10000
# 4   Charlie   28   25000
# 5   Charlie   28   30000
# 6    robert   28   15000

# %% [markdown]
# ///Task-3 df.drop_duplicates(subset=['col1', 'col2'], keep='first', inplace=True)

# %%
drop_col=df.drop_duplicates(subset=['age'],keep='first')
print("Remove duplicate based on age column:\n",drop_col)
drop_colu=df.drop_duplicates(subset=['name','age'],keep='first')
print("Remove duplicated based on the name and age coulumn\n",drop_colu)
# Out:
# Remove duplicate based on age column:
#         name  age  salary
# 0  John Doe   25   50000
# 1     Alice   30   25000
# 2       Bob   22   10000
# 4   Charlie   28   25000
# Remove duplicated based on the name and age coulumn
#         name  age  salary
# 0  John Doe   25   50000
# 1     Alice   30   25000
# 2       Bob   22   10000
# 4   Charlie   28   25000
# 6    robert   28   15000

# %% [markdown]
# ///Task-4 df['col'].is_unique

# %%
uni=df['name'].is_unique
print("check the name cloumns unique or not(True->unique)\n",uni)
# Out:
# check the name cloumns unique or not(True->unique)
#  False
